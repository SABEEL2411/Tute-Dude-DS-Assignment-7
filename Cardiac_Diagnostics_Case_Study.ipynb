# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib.colors import ListedColormap
from scipy.stats import boxcox

from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import classification_report, accuracy_score

# %%
# Set the resolution of the plotted figures
plt.rcParams['figure.dpi'] = 200

# Configure Seaborn plot style: set background color and use dark grid
sns.set(style='darkgrid', rc={'axes.facecolor': '#faded9'})

# %%
# Read Dataset 
df = pd.read_csv("heart_disease_uci.csv")
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    str
#  3   dataset   920 non-null    str
#  4   cp        920 non-null    str
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    str
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    str
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    str
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(2), str(6)
# memory usage: 115.1+ KB

# %%
continuous_features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# Keep only columns that actually exist in df
continuous_features = [col for col in continuous_features if col in df.columns]

features_to_convert = [col for col in df.columns if col not in continuous_features]

df[features_to_convert] = df[features_to_convert].astype('object')

df.dtypes
# Out:
# id           object
# age           int64
# sex          object
# dataset      object
# cp           object
# trestbps    float64
# chol        float64
# fbs          object
# restecg      object
# thalch       object
# exang        object
# oldpeak     float64
# slope        object
# ca           object
# thal         object
# num          object
# dtype: object

# %%
# Get summary statistic for numerical variables 
df.describe().T
# Out:
#           count        mean         std   min    25%    50%    75%    max
# age       920.0   53.510870    9.424685  28.0   47.0   54.0   60.0   77.0
# trestbps  861.0  132.132404   19.066070   0.0  120.0  130.0  140.0  200.0
# chol      890.0  199.130337  110.780810   0.0  175.0  223.0  268.0  603.0
# oldpeak   858.0    0.878788    1.091226  -2.6    0.0    0.5    1.5    6.2

# %%
# Get summary statistic for categorical variables 
df.describe(include = object)
# Out:
#          id   sex    dataset            cp    fbs restecg  thalch  exang  \
# count   920   920        920           920    830     918   865.0    865
# unique  920     2          4             4      2       3   119.0      2
# top       1  Male  Cleveland  asymptomatic  False  normal   150.0  False
# freq      1   726        304           496    692     551    43.0    528
#
#        slope     ca    thal  num
# count    611  309.0     434  920
# unique     3    4.0       3    5
# top     flat    0.0  normal    0
# freq     345  181.0     196  411

# %%
# Filter out continuous features for the univariate analysis
existing_cont_features = [col for col in continuous_features if col in df.columns]
df_continuous = df[existing_cont_features].dropna()

# Set up the subplot
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))

# Loop to plot histograms for each continuous feature
for i, col in enumerate(df_continuous.columns):
    x = i // 3
    y = i % 3

    # Compute histogram bins safely
    values, bin_edges = np.histogram(
        df_continuous[col],
        bins=10,
        range=(np.floor(df_continuous[col].min()), np.ceil(df_continuous[col].max()))
    )

    graph = sns.histplot(
        data=df_continuous,
        x=col,
        bins=bin_edges,
        kde=True,
        ax=ax[x, y],
        edgecolor='none',
        color='red',
        alpha=0.6,
        line_kws={'lw': 3}
    )

    ax[x, y].set_xlabel(col, fontsize=15)
    ax[x, y].set_ylabel('Count', fontsize=12)
    ax[x, y].set_xticks(np.round(bin_edges, 1))
    ax[x, y].set_xticklabels(ax[x, y].get_xticks(), rotation=45)
    ax[x, y].grid(color='lightgrey')

    # Annotate bar heights
    for p in graph.patches:
        height = int(p.get_height())
        if height > 0:
            ax[x, y].annotate(
                f'{height}',
                (p.get_x() + p.get_width() / 2, height + 1),
                ha='center',
                fontsize=10,
                fontweight='bold'
            )

    # Mean and Std box
    textstr = '\n'.join((
        r'$\mu=%.2f$' % df_continuous[col].mean(),
        r'$\sigma=%.2f$' % df_continuous[col].std()
    ))

    ax[x, y].text(
        0.75, 0.9, textstr,
        transform=ax[x, y].transAxes,
        fontsize=12,
        verticalalignment='top',
        color='white',
        bbox=dict(boxstyle='round', facecolor='#ff826e', edgecolor='white', pad=0.5)
    )

# Turn off unused subplots automatically
total_plots = len(df_continuous.columns)
for j in range(total_plots, 6):
    fig.delaxes(ax[j // 3][j % 3])

plt.suptitle('Distribution of Continuous Variables', fontsize=20)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Get only the continuous features that actually exist in the dataframe
existing_cont_features = [col for col in continuous_features if col in df.columns]

# Filter out categorical features
categorical_features = [col for col in df.columns if col not in existing_cont_features]

# Create categorical dataframe
df_categorical = df[categorical_features]

# %%
# Number of categorical features
n_features = len(categorical_features)

# Set columns fixed at 2
cols = 2

# Compute required rows dynamically
rows = int(np.ceil(n_features / cols))

fig, ax = plt.subplots(nrows=rows, ncols=cols, figsize=(15, rows * 3.5))

# If only one row, make ax 2D for consistent indexing
if rows == 1:
    ax = np.array([ax])

for i, col in enumerate(categorical_features):
    row = i // cols
    col_idx = i % cols

    value_counts = df[col].value_counts(normalize=True).mul(100).sort_values()

    value_counts.plot(
        kind='barh',
        ax=ax[row, col_idx],
        width=0.8,
        color='red'
    )

    # Add percentage labels
    for index, value in enumerate(value_counts):
        ax[row, col_idx].text(
            value,
            index,
            f"{round(value, 1)}%",
            fontsize=12,
            weight='bold',
            va='center'
        )

    ax[row, col_idx].set_xlim([0, 100])
    ax[row, col_idx].set_xlabel('Frequency Percentage', fontsize=11)
    ax[row, col_idx].set_title(col, fontsize=14)
    ax[row, col_idx].grid(axis='x', color='lightgrey')

# Remove unused subplots
total_plots = rows * cols
for j in range(n_features, total_plots):
    fig.delaxes(ax[j // cols][j % cols])

plt.suptitle('Distribution of Categorical Variables', fontsize=20)
plt.tight_layout()
plt.subplots_adjust(top=0.95)
plt.show()

# %%
# Automatically detect target column
possible_targets = ['target', 'num', 'Outcome']

target_col = None
for col in possible_targets:
    if col in df.columns:
        target_col = col
        break

if target_col is None:
    raise ValueError("Target column not found. Please check df.columns")

print("Using target column:", target_col)

# Keep only continuous features that exist
existing_cont_features = [col for col in continuous_features if col in df.columns]

# Create subplots
fig, ax = plt.subplots(
    len(existing_cont_features),
    2,
    figsize=(15, 5 * len(existing_cont_features)),
    gridspec_kw={'width_ratios': [1, 2]}
)

if len(existing_cont_features) == 1:
    ax = np.array([ax])

for i, col in enumerate(existing_cont_features):

    # Barplot of mean values per class
    graph = sns.barplot(data=df, x=target_col, y=col, ax=ax[i, 0])

    # KDE distributions
    sns.kdeplot(
        data=df[df[target_col] == 0],
        x=col,
        fill=True,
        linewidth=2,
        ax=ax[i, 1],
        label='0'
    )

    sns.kdeplot(
        data=df[df[target_col] == 1],
        x=col,
        fill=True,
        linewidth=2,
        ax=ax[i, 1],
        label='1'
    )

    ax[i, 1].set_yticks([])
    ax[i, 1].legend(title='Class', loc='upper right')

    # Add mean labels on barplot
    for container in graph.containers:
        graph.bar_label(container, fmt='%.3g')

plt.suptitle('Continuous Features vs Target Distribution', fontsize=22)
plt.tight_layout()
plt.subplots_adjust(top=0.95)
plt.show()
# Out:
# Using target column: num

# %%
# Remove 'target' from the categorical_features
categorical_features = [feature for feature in categorical_features if feature != 'target']

# %%
# ==============================
# Use correct target column
# ==============================
target_col = 'num'

# Convert target to binary (0 = no disease, 1 = disease)
df[target_col] = df[target_col].apply(lambda x: 1 if x > 0 else 0)

# ==============================
# Clean categorical features (remove target if present)
# ==============================
categorical_features = [col for col in categorical_features if col != target_col]

# Replace '?' with NaN (present in UCI dataset) and drop for plotting
df.replace('?', np.nan, inplace=True)

# ==============================
# Dynamic subplot size
# ==============================
n_features = len(categorical_features)
cols = 4
rows = int(np.ceil(n_features / cols))

fig, ax = plt.subplots(rows, cols, figsize=(16, 4 * rows))

if rows == 1:
    ax = np.array([ax])

cmp = ListedColormap(['#ff826e', 'red'])

# ==============================
# Plot stacked bar charts
# ==============================
for i, col in enumerate(categorical_features):

    row = i // cols
    col_idx = i % cols

    # Drop NaN only for current column to avoid losing full rows
    temp_df = df[[col, target_col]].dropna()

    # Crosstab counts
    cross_tab = pd.crosstab(index=temp_df[col], columns=temp_df[target_col])

    # Crosstab proportions
    cross_tab_prop = pd.crosstab(
        index=temp_df[col],
        columns=temp_df[target_col],
        normalize='index'
    )

    # Plot stacked bars
    cross_tab_prop.plot(
        kind='bar',
        ax=ax[row, col_idx],
        stacked=True,
        width=0.8,
        colormap=cmp,
        legend=False,
        ylabel='Proportion',
        sharey=True
    )

    # Add count + percentage labels
    for idx, val in enumerate(cross_tab.index.values):
        for proportion, count, y_loc in zip(
            cross_tab_prop.loc[val],
            cross_tab.loc[val],
            cross_tab_prop.loc[val].cumsum()
        ):
            ax[row, col_idx].text(
                x=idx,
                y=(y_loc - proportion) + (proportion / 2),
                s=f'{count}\n({np.round(proportion * 100, 1)}%)',
                ha='center',
                fontsize=9,
                fontweight='bold'
            )

    ax[row, col_idx].legend(title=target_col, fontsize=8)
    ax[row, col_idx].set_ylim([0, 1.12])
    ax[row, col_idx].set_title(col)
    ax[row, col_idx].set_xticklabels(
        ax[row, col_idx].get_xticklabels(),
        rotation=0
    )

# ==============================
# Remove unused subplots
# ==============================
total_plots = rows * cols
for j in range(n_features, total_plots):
    fig.delaxes(ax[j // cols][j % cols])

plt.suptitle('Categorical Features vs Target Stacked Barplots', fontsize=20)
plt.tight_layout()
plt.subplots_adjust(top=0.95)
plt.show()

# %%
# Check for missing values in dataset 
df.isnull().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %%
continuous_features
# Out:
# ['age', 'trestbps', 'chol', 'oldpeak']

# %%
continuous_features = df.select_dtypes(include=['int64', 'float64']).columns.drop('num')

Q1 = df[continuous_features].quantile(0.25)
Q3 = df[continuous_features].quantile(0.75)
IQR = Q3 - Q1
outliers_count_specified = ((df[continuous_features] < (Q1 - 1.5 * IQR)) | (df[continuous_features] > (Q3 + 1.5 * IQR))).sum()
outliers_count_specified
# Out:
# age           0
# trestbps     28
# chol        183
# oldpeak      16
# dtype: int64

# %%
# Implement one-hot encoding on available categorical features
ohe_cols = [col for col in ['cp', 'restecg', 'thal'] if col in df.columns]
df_encoded = pd.get_dummies(df, columns=ohe_cols, drop_first=True)

# Convert remaining categorical/binary columns to int if they exist
features_to_convert = [col for col in ['sex', 'fbs', 'exang', 'slope', 'ca', 'num'] if col in df_encoded.columns]

for feature in features_to_convert:
    df_encoded[feature] = pd.to_numeric(df_encoded[feature], errors='coerce').astype('Int64')

df_encoded.dtypes
# Out:
# id                           object
# age                           int64
# sex                           Int64
# dataset                      object
# trestbps                    float64
# chol                        float64
# fbs                           Int64
# thalch                       object
# exang                         Int64
# oldpeak                     float64
# slope                         Int64
# ca                            Int64
# num                           Int64
# cp_atypical angina             bool
# cp_non-anginal                 bool
# cp_typical angina              bool
# restecg_normal                 bool
# restecg_st-t abnormality       bool
# thal_normal                    bool
# thal_reversable defect         bool
# dtype: object

# %%
# Displaying the result dataset after one heat encoding 
df_encoded.head()
# Out:
#   id  age   sex    dataset  trestbps   chol  fbs thalch  exang  oldpeak  \
# 0  1   63  <NA>  Cleveland     145.0  233.0    1  150.0      0      2.3
# 1  2   67  <NA>  Cleveland     160.0  286.0    0  108.0      1      1.5
# 2  3   67  <NA>  Cleveland     120.0  229.0    0  129.0      1      2.6
# 3  4   37  <NA>  Cleveland     130.0  250.0    0  187.0      0      3.5
# 4  5   41  <NA>  Cleveland     130.0  204.0    0  172.0      0      1.4
#
#    slope  ca  num  cp_atypical angina  cp_non-anginal  cp_typical angina  \
# 0   <NA>   0    0               False           False               True
# 1   <NA>   3    1               False           False              False
# 2   <NA>   2    1               False           False              False
# 3   <NA>   0    0               False            True              False
# 4   <NA>   0    0                True           False              False
#
#    restecg_normal  restecg_st-t abnormality  thal_normal  \
# ...

# %%
# Define features (X) and output labels (y)
X = df_encoded.drop('num', axis=1)
y = df_encoded['num']

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0, stratify=y
)

# %%
X_train.shape,X_test.shape
# Out:
# ((736, 19), (184, 19))

# %%
 continuous_features
# Out:
# Index(['age', 'trestbps', 'chol', 'oldpeak'], dtype='str')

# %%
# Add small constant to oldpeak
if 'oldpeak' in X_train.columns:
    X_train['oldpeak'] = X_train['oldpeak'] + 0.001
    X_test['oldpeak'] = X_test['oldpeak'] + 0.001

# Plot distributions and apply Box-Cox
fig, ax = plt.subplots(2, len(continuous_features), figsize=(15, 10))

lambdas = {}

for i, col in enumerate(continuous_features):

    # Original distribution
    sns.histplot(X_train[col], kde=True, ax=ax[0, i], color='#ff826e')
    ax[0, i].set_title(f'Original {col}')

    # Box-Cox only if positive
    if X_train[col].min() > 0:
        X_train[col], lambdas[col] = boxcox(X_train[col])
        X_test[col] = boxcox(X_test[col], lmbda=lambdas[col])

        sns.histplot(X_train[col], kde=True, ax=ax[1, i], color='red')
        ax[1, i].set_title(f'Transformed {col}')
    else:
        sns.histplot(X_train[col], kde=True, ax=ax[1, i], color='green')
        ax[1, i].set_title(f'{col} (Not Transformed)')

fig.tight_layout()
plt.show()

# %%
X_train.head()
# Out:
#       id         age   sex        dataset  trestbps   chol  fbs thalch  exang  \
# 398  399  107.596834  <NA>        Hungary     120.0  254.0    0  110.0      0
# 418  419  113.376496  <NA>        Hungary     150.0  215.0    0  140.0      1
# 810  811  190.476770  <NA>  VA Long Beach     136.0  225.0    0  112.0      1
# 164  165  107.596834  <NA>      Cleveland     124.0  255.0    1  175.0      0
# 159  160  168.053905  <NA>      Cleveland     118.0  277.0    0  151.0      0
#
#      oldpeak  slope    ca  cp_atypical angina  cp_non-anginal  \
# 398    0.001   <NA>  <NA>               False           False
# 418    0.001   <NA>  <NA>               False           False
# 810    3.001   <NA>  <NA>               False           False
# 164    0.001   <NA>     2               False            True
# 159    1.001   <NA>     1               False            True
#
#      cp_typical angina  restecg_normal  restecg_st-t abnormality  thal_normal  \
# ...
